# %%
int a=5
float b=3.4
# Out:
#   Cell In[1], line 1
#     int a=5
#         ^
# SyntaxError: invalid syntax

# %%
a=5245545544545454
print(a)
print(type(a))
print(id(a))

# %%
a=5
print(a)
print(type(a))

# %% [markdown]
# # string data type

# %%
s="karunadu technologies"
print(s)
print(type(s))

# %%
s[1]

# %%
s[-1]

# %%
s[0:8:2]

# %%
s[0:8]

# %%
s.index("")

# %%
s.index("s")

# %%
s

# %%
s.upper()

# %%
s.lower()

# %%
s.split()

# %%
dir(str)

# %%
s.title()

# %%
s1="hello"
s2="pradeep"
print(s1.join(s2))

# %%
s1="hello"
s2="pradeep"
print(s1+s2)

# %%
s.swapcase()

# %% [markdown]
# # boolean data type

# %%
bool(1)

# %%
bool(0)

# %%
print(True+True)

# %%
print(True+True+bool(-1))

# %%
print(True+True+bool)

# %% [markdown]
# # complex number

# %%
c=2+3j
print(c)
print(type(c))

# %%
c.imag

# %%
c.real+c.imag

# %% [raw]
# c.real

# %%
f_name="karunadu"
l_name="tech"
f_name=f_name+" " +l_name
print(f_name)

# %%
s* 2

# %%
"karunadu"+str( 13)

# %% [markdown]
# # type casting

# %%
a=2
print(a)
print(type(a))

# %%
b=float(a)
print(b)
print(type(a))

# %%
c=str(a)
print(c)
print(type(c))

# %%
a=2
d=char(a)
print(d)
print(type(d))

# %%
s="ten"
a=int(s)

# %%
s.isnumeric()

# %%
s.isnumeric()

# %%
import keyword
keyword.kwlist

# %%
f_name=input("enter first name")
l_name=input("enter the last name")
f_name=f_name+" " +l_name
print("full name:",f_name)

# %%
f_name=input("enter first name")
l_name=input("enter the last name")
f_name=f_name+" " +l_name
print("full name:",f_name)
# Out:
# enter first name pradeep
# enter the last name nagappa
# full name: pradeep nagappa

# %%
f_name=input("enter first name: ")
l_name=input("enter the last name: ")
fav_number =int(intput("enter your favorite number: "))
fav_number +=5
email_id=f"{f_name}{l_name}{fav_number}@gmail.com"
print("generated email id :",email_id)
# Out:
# enter first name:  pradeep
# enter the last name:  nh
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 3
#       1 f_name=input("enter first name: ")
#       2 l_name=input("enter the last name: ")
# ----> 3 fav_number =int(intput("enter your favorite number: "))
#       4 fav_number +=5
#       5 email_id=f"{f_name}{l_name}{fav_number}@gmail.com"
#
# NameError: name 'intput' is not defined

# %%
f_name = input("enter first name: ")
l_name = input("enter the last name: ")
fav_number = int(input("enter your favorite number: ")) 
fav_number += 5
email_id = f"{f_name}{l_name}{fav_number}@gmail.com"
print("generated email id:", email_id)
# Out:
# enter first name:  pradeep
# enter the last name:  nh
# enter your favorite number:  13
# generated email id: pradeepnh18@gmail.com

# %%
f_name = input("enter first name: ").lower()
l_name = input("enter the last name: ").lower()
fav_number = int(input("enter your favorite number: ")) 
fav_number += 5
email_id = f"{f_name}{l_name}{fav_number}@gmail.com"
print("generated email id:", email_id)
# Out:
# enter first name:  pradeep
# enter the last name:  nh
# enter your favorite number:  13
# generated email id: pradeepnh18@gmail.com

# %%
f_name = input("enter first name: ").lower()
l_name = input("enter the last name: ").lower()
fav_number = int(input("enter your favorite number: "))+5
email_id = f"{f_name}{l_name}{fav_number}@gmail.com"
print("generated email id:", email_id)
# Out:
# enter first name:  PRADEEP
# enter the last name:  NH
# enter your favorite number:  13
# generated email id: pradeepnh18@gmail.com
