# %%
##tuple(immutable,,, not able to do any modification)
t=(1,2,3,4,"hi",2,3,3,4,5,6)
print(type(t))
print(t)
print(len(t))
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 'hi', 2, 3, 3, 4, 5, 6)
# 11

# %%
dir(t)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
t
# Out:
# (1, 2, 3, 4, 'hi', 2, 3, 3, 4, 5, 6)

# %%
t.appened(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 t.appened(2)
#
# AttributeError: 'tuple' object has no attribute 'appened'

# %%
t.count(2)
# Out:
# 2

# %%
t.index(6)
# Out:
# 10

# %%
t=(1,2,3,4,45)
print("max:",max(t))
print("min:",min(t))
print("sum:",sum(t))
# Out:
# max: 45
# min: 1
# sum: 55

# %%
t=(1,2,3,4,45)
l=list(t)
print(l)
l[3]=123
print(l)
t=tuple(l)
print(t)
# Out:
# [1, 2, 3, 4, 45]
# [1, 2, 3, 123, 45]
# (1, 2, 3, 123, 45)

# %%
t=(21,1,3,4)
a,b,c,d=t
print(a)
print(b)
# Out:
# 21
# 1

# %% [markdown]
# # set

# %%
s={2,1,3,4,1,3,"hello",2,3,4,1,5,6,"pnh"}
print(type(s))
print(len(s))
print(s)
# Out:
# <class 'set'>
# 8
# {1, 2, 3, 4, 5, 6, 'hello', 'pnh'}

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6, 'hello', 'pnh'}

# %%
s.add(13)

# %%
s
# Out:
# {1, 13, 2, 3, 4, 5, 6, 'hello', 'pnh'}

# %%
s.update(["pnh",13,False,True])

# %%
s
# Out:
# {1, 13, 2, 3, 4, 5, 6, False, 'True', 'hello', 'pnh'}

# %%
s = {13}
s.update(["pnh", 13, False, True])
print(s)
# Out:
# {False, True, 13, 'pnh'}

# %%
s.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 s.pop(13)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
s.remove("pnh")

# %%
s
# Out:
# {'pnh'}

# %%
s
# Out:
# set()

# %%
s={2,3,4,5,6,7,49}
print("max:",max(s))
print("min:",min(s))
print("sum:",sum(s))
# Out:
# max: 49
# min: 2
# sum: 76

# %%
a={1,2,3,4}
b={1,3,4,5,6}
print(a|b)# IT Combines and removesduplicates
print(a&b)
print(a-b)
print(a^b)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 3, 4}
# {2}
# {2, 5, 6}
