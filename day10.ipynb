# %%
import random
otp=random.randint(1000,9999)
print(otp)
n=int(input("enter the otp"))
if n==otp:
    print("verification succesful")
else:
    print("invalid otp")
# Out:
# 9228
# enter the otp 9228
# verification succesful

# %%
import random
import time
otp=random.randint(1000,9999)
print("your otp is:",otp)
start_time=time.time()
n=int(input("enter the otp"))
end_time=time.time()
if end_time-start_time>10:
    print("otp expired")
elif n==otp:
    print("verification succesful")
else:
    print("invalid otp")
# Out:
# your otp is: 7063
# enter the otp 7063
# otp expired

# %%
import random
import time
username=["user1","user2","user3","user4","user5"]
password=["pass1","pass2","pass3","pass4","pass5"]
usr=input("enter the user name:")#user1
if usr in username:
    print("valid user name:")
    i=username.index(usr)#0
    print(i)
    pwd=input("enter the password:")#pass4
    if pwd==password[i]:#pass4==pass1
        print("valid password login succesfully")
        otp=random.randint(1000,9999)
        print("your otp is:",otp)
        start_time=time.time()
        n=int(input("enter the otp"))
        end_time=time.time()
        if end_time-start_time>10:
            print("otp expired")
    elif n==otp:
        print("verification succesful")
    else:
        print("invalid otp")
    else:
        print("invalid password")
else:
    print("invalid user name:")
# Out:
#   Cell In[42], line 24
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
import random
import time

username = ["user1", "user2", "user3", "user4", "user5"]
password = ["pass1", "pass2", "pass3", "pass4", "pass5"]

usr = input("Enter the user name: ")

if usr in username:
    print("Valid user name")
    i = username.index(usr)
    pwd = input("Enter the password: ")
    
    if pwd == password[i]:
        print("Valid password. Login successfully!")
        
        # --- OTP Generation ---
        otp = random.randint(1000, 9999)
        print("Your OTP is:", otp)
        
        start_time = time.time()
        n = int(input("Enter the OTP: "))
        end_time = time.time()
        
        # --- OTP Verification ---
        if end_time - start_time > 10:
            print("OTP expired (Took more than 10 seconds)")
        elif n == otp:
            print("Verification successful!")
        else:
            print("Invalid OTP")
            
    else:
        print("Invalid password")
else:
    print("Invalid user name")
# Out:
# Enter the user name:  user1
# Valid user name
# Enter the password:  pass1
# Valid password. Login successfully!
# Your OTP is: 4019
# Enter the OTP:  4019
# Verification successful!

# %% [markdown]
# # file handing

# %%
1.text file =>.txt
2.binary.file
(video or audio image)

# %%
f=open(file namewith.txt,mode)
x create new file
w to write
a append
r read
close()

# %%
f=open("abc.txt","x")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 f=open("abc.txt","x")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'abc.txt'

# %%
f=open("abcd.txt","x")

# %%
f=open("abcd.txt","w")
f.write("hi good evening\n")
f.write("pradeeep\n")
f.write("be student\n")
f.close()

# %%
f=open("abcd.txt","a")
f.write("new file is added")
f.close()

# %%
f=open("students.txt","w")
n=int(input("enter the number of students:"))
for i in range(n):
    name=input("enter the name:")
    marks=input("enter the marks:")
    f.write(name+"="+marks+"data\n")
print("data written successfully")
f.close()
# Out:
# enter the number of students: 1
# enter the name: 13
# enter the marks: 2
# data written successfully

# %%
f=open("abcd.txt","r")
print(f.read(20))
# Out:
# hi good evening
# prad

# %%
f=open("abcd.txt","r")
print(f.readlines())
# Out:
# ['hi good evening\n', 'pradeeep\n', 'be student\n', 'new file is added']

# %%
import time 
f=open("abcd.txt","r")
for i in f:
    print(i)
    time.sleep(1)
# Out:
# hi good evening
#
# pradeeep
#
# be student
#
# new file is added

# %% [markdown]
# # count line , words and characters

# %%
f=open("abcd.txt","r")
data=f.read()
lines=data.split("\n")
words=data.split()
print(data)
print("no of line:",len(lines))
print("no of words:",len(words))
print("characters:",len(data))
f.close()
# Out:
# hi good evening
# pradeeep
# be student
# new file is added
# no of line: 4
# no of words: 10
# characters: 53

# %%
import os
if os.path.exists("abc.txt"):
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
import os
if os.path.exists("abc.txt"):
    os.remove("abc.txt")
    print("yes")
else:
    print("no")
# Out:
# no

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp\\OneDrive\\Documents\\Custom Office Templates\\Desktop\\internship'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'abcd.txt',
#  'activity day09.ipynb',
#  'anaconda_projects',
#  'calci.py',
#  'day01.ipynb',
#  'day04 activity.ipynb',
#  'day04.ipynb',
#  'day05.ipynb',
#  'day08.ipynb',
#  'day09.ipynb',
#  'day10.ipynb',
#  'day2.ipynb',
#  'day3 activity.ipynb',
#  'day3.ipynb',
#  'day6.ipynb',
#  'day7.ipynb',
#  'New Text Document.txt',
#  'students.txt',
#  'Untitled.ipynb',
#  '__pycache__']
