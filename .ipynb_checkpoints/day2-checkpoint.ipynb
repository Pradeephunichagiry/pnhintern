# %%
int a=5
float b=3.4
# Out:
#   Cell In[9], line 1
#     int a=5
#         ^
# SyntaxError: invalid syntax

# %%
a=5245545544545454
print(a)
print(type(a))
print(id(a))
# Out:
# 5245545544545454
# <class 'int'>
# 1344740390800

# %%
a=5
print(a)
print(type(a))
# Out:
# 5
# <class 'int'>

# %% [markdown]
# # string data type

# %%
s="karunadu technologies"
print(s)
print(type(s))
# Out:
# karunadu technologies
# <class 'str'>

# %%
s[1]
# Out:
# 'a'

# %%
s[-1]

# %%
s[0:8:2]
# Out:
# 'krnd'

# %%
s[0:8]
# Out:
# 'karunadu'

# %%
s.index("")
# Out:
# 0

# %%
s.index("s")
# Out:
# 20

# %%
s
# Out:
# 'karunadu technologies'

# %%
s.upper()
# Out:
# 'KARUNADU TECHNOLOGIES'

# %%
s.lower()
# Out:
# 'karunadu technologies'

# %%
s.split()
# Out:
# ['karunadu', 'technologies']

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
s.title()
# Out:
# 'Karunadu Technologies'

# %%
s1="hello"
s2="pradeep"
print(s1.join(s2))
# Out:
# phellorhelloahellodhelloehelloehellop

# %%
s1="hello"
s2="pradeep"
print(s1+s2)
# Out:
# hellopradeep

# %%
s.swapcase()
# Out:
# 'KARUNADU TECHNOLOGIES'

# %% [markdown]
# # boolean data type

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
print(True+True)
# Out:
# 2

# %%
print(True+True+bool(-1))
# Out:
# 3

# %%
print(True+True+bool)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 print(True+True+bool)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'type'

# %% [markdown]
# # complex number

# %%
c=2+3j
print(c)
print(type(c))
# Out:
# (2+3j)
# <class 'complex'>

# %%
c.imag
# Out:
# 3.0

# %%
c.real+c.imag
# Out:
# 5.0

# %% [raw]
# c.real

# %%
f_name="karunadu"
l_name="tech"
f_name=f_name+" " +l_name
print(f_name)
# Out:
# karunadu tech

# %%
s* 2
# Out:
# 'karunadu technologieskarunadu technologies'

# %%
"karunadu"+str( 13)
# Out:
# 'karunadu13'

# %% [markdown]
# # type casting

# %%
a=2
print(a)
print(type(a))
# Out:
# 2
# <class 'int'>

# %%
b=float(a)
print(b)
print(type(a))
# Out:
# 2.0
# <class 'int'>

# %%
c=str(a)
print(c)
print(type(c))
# Out:
# 2
# <class 'str'>

# %%
a=2
d=char(a)
print(d)
print(type(d))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[156], line 2
#       1 a=2
# ----> 2 d=char(a)
#       3 print(d)
#       4 print(type(d))
#
# NameError: name 'char' is not defined

# %%
s="ten"
a=int(s)

# %%
s.isnumeric()
# Out:
# True

# %%
s.isnumeric()
# Out:
# True
